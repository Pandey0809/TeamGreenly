# %% [markdown]
# <a href="https://colab.research.google.com/github/Pandey0809/TeamGreenly/blob/main/DataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from plotnine import ggplot, aes, geom_line
import seaborn as sns

# %% [markdown]
# https://realpython.com/ggplot-python/ : python ggplot tutorial
#
# https://matplotlib.org/stable/plot_types/stats/boxplot_plot.html#sphx-glr-plot-types-stats-boxplot-plot-py :box plot
#
# https://matplotlib.org/stable/plot_types/stats/violin.html#sphx-glr-plot-types-stats-violin-py : violinplot

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4c04486d-54d4-4c2b-946c-fe99883a52b8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4c04486d-54d4-4c2b-946c-fe99883a52b8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dataNativeNokia = pd.read_csv('nativeNokiafinal.csv',sep=',',index_col=False)
dataWebNokia = pd.read_csv('WebNokiafinal.csv',sep=',',index_col=False)

# %%
dataNativeNokia.drop('Unnamed: 0',inplace=True,axis=1)
dataWebNokia.drop('Unnamed: 0',inplace=True,axis=1)

# %%
dataWebNokia.head()
# Out:
#    facebook_messenger  google_maps  google_keep   facebook      gmail  \
# 0           19.543392    35.146584    35.304192  43.342200  35.934624
# 1           18.755352    34.200936    35.777016  39.244392  46.809576
# 2           17.967312    26.320536    49.488912  40.190040  53.901936
# 3           22.380336    35.146584    49.488912  40.662864  43.184592
# 4           20.489040    37.195488    46.967184  49.331304  48.543264
#
#      netflix    spotify     tiktok    twitter    youtube
# 0  17.494488  29.157480  27.322236  25.427052  25.847712
# 1  24.586848  23.325984  25.217280  21.592296  28.211832
# 2  61.782336  21.907512  26.793360  24.429240  27.739008
# 3  55.950840  23.641200  25.690104  26.950968  29.472696
# 4  26.635752  21.907512  29.630304  32.309640  44.445456

# %%
dataNativeNokia.head()
# Out:
#    facebook  facebook_messenger  google_maps     gmail  google_keep   youtube  \
# 0  55.98720            26.81856    51.978240  56.40192     65.66400  28.89216
# 1  49.76640            35.11296    41.610240  37.87776     63.03744  40.08960
# 2  57.09312            23.50080    39.813120  36.77184     74.78784  34.42176
# 3  72.43776            40.22784    37.617552  42.30144     80.73216  39.12192
# 4  61.10208            39.39840    37.696752  51.42528     61.37856  61.10208
#
#     netflix   spotify     tiktok   twitter
# 0  15.89760  47.13984  65.802240  31.93344
# 1  20.73600  47.83104  47.831040  22.94784
# 2  15.34464  46.44864  56.816640  21.28896
# 3  20.32128  66.35520  47.554560  22.39488
# 4  14.51520  59.44320  40.986288  21.42720

# %%
dataWebNokia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   facebook_messenger  20 non-null     float64
#  1   google_maps         20 non-null     float64
#  2   google_keep         20 non-null     float64
#  3   facebook            20 non-null     float64
#  4   gmail               20 non-null     float64
#  5   netflix             20 non-null     float64
#  6   spotify             20 non-null     float64
#  7   tiktok              20 non-null     float64
#  8   twitter             20 non-null     float64
#  9   youtube             20 non-null     float64
# dtypes: float64(10)
# memory usage: 1.7 KB

# %%
dataNativeNokia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   facebook            20 non-null     float64
#  1   facebook_messenger  20 non-null     float64
#  2   google_maps         20 non-null     float64
#  3   gmail               20 non-null     float64
#  4   google_keep         20 non-null     float64
#  5   youtube             20 non-null     float64
#  6   netflix             20 non-null     float64
#  7   spotify             20 non-null     float64
#  8   tiktok              20 non-null     float64
#  9   twitter             20 non-null     float64
# dtypes: float64(10)
# memory usage: 1.7 KB

# %%
dataWebNokia.describe()
# Out:
#        facebook_messenger  google_maps  google_keep   facebook      gmail  \
# count           20.000000    20.000000    20.000000  20.000000  20.000000
# mean            22.734954    36.320764    44.894639  41.119927  47.187835
# std              2.411955     4.421156     6.465928   4.293770   9.717547
# min             17.967312    26.320536    33.885720  29.157480  35.777016
# 25%             21.907512    35.146584    37.628910  39.007980  43.066386
# 50%             22.774356    36.801468    47.124792  41.056884  45.075888
# 75%             23.995818    37.550106    49.134294  42.948180  48.425058
# max             28.369440    47.282400    53.901936  49.331304  83.059416
#
#          netflix    spotify     tiktok    twitter    youtube
# count  20.000000  20.000000  20.000000  20.000000  20.000000
# mean   33.452298  29.504218  29.987725  30.893776  37.644671
# std    17.554348   6.710279   4.267779  11.887982  10.939293
# ...

# %%
dataNativeNokia.describe()
# Out:
#         facebook  facebook_messenger  google_maps      gmail  google_keep  \
# count  20.000000           20.000000    20.000000  20.000000    20.000000
# mean   51.586771           22.119912    37.396112  34.331956    56.929334
# std    15.325852            7.675336     4.303167   7.931627    12.220224
# min    35.364384           15.073344    33.770088  28.552392    45.654840
# 25%    39.005982           17.102448    34.458534  29.132136    46.669392
# 50%    47.783088           18.189468    36.099540  30.041856    50.744772
# 75%    59.235840           23.966550    38.541906  37.048320    64.005120
# max    96.906240           40.227840    51.978240  56.401920    80.732160
#
#          youtube    netflix    spotify     tiktok    twitter
# count  20.000000  20.000000  20.000000  20.000000  20.000000
# mean   30.152677  15.398533  34.664677  42.395515  22.997480
# std     8.952739   3.605296  15.450023   7.681621   6.352428
# ...

# %%
dataNativeNokia.columns
# Out:
# Index(['facebook', 'facebook_messenger', 'google_maps', 'gmail', 'google_keep',
#        'youtube', 'netflix', 'spotify', 'tiktok', 'twitter'],
#       dtype='object')

# %%
columns = ["facebook", "google_maps", "facebook_messenger","tiktok",
               "gmail", "netflix","spotify","twitter","google_keep","youtube"]
for i in columns:
  plt.figure(figsize=(7,5))
  x1 = list(dataNativeNokia[i])
  x2 = list(dataWebNokia[i])
  colors = ['red', 'blue']
  names = [f'Native',f'Web']
  sns.distplot(x1,hist=True, kde=True,bins=int(180/5), color = 'blue', hist_kws={'edgecolor':'black'},kde_kws={'linewidth': 4},label=f'Native')
  sns.distplot(x2,hist=True, kde=True,bins=int(180/5), color = 'red', hist_kws={'edgecolor':'black'},kde_kws={'linewidth': 4},label=f'Web')
  plt.legend()
  plt.xlabel('Energy consumption in Joule')
  plt.ylabel('Trails')
  plt.title(f'Side-by-Side Histogram Native vs Web Apps for {i} platform')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ...

# %%
import numpy as np
import statsmodels.api as sm
import pylab as py
sm.qqplot(dataNativeNokia['facebook'], line ='45')
py.show()
